# %%
import numpy as np

import pandas as pd

Data_set = pd.read_csv('/content/drive/MyDrive/compresive_strength_concrete.csv')

# %%
Data_set.head()
# Out:
#    Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# 0                                      540.0  ...                                             79.99
# 1                                      540.0  ...                                             61.89
# 2                                      332.5  ...                                             40.27
# 3                                      332.5  ...                                             41.05
# 4                                      198.6  ...                                             44.30
#
# [5 rows x 9 columns]

# %%
Data_set.columns
# Out:
# Index(['Cement (component 1)(kg in a m^3 mixture)',
#        'Blast Furnace Slag (component 2)(kg in a m^3 mixture)',
#        'Fly Ash (component 3)(kg in a m^3 mixture)',
#        'Water  (component 4)(kg in a m^3 mixture)',
#        'Superplasticizer (component 5)(kg in a m^3 mixture)',
#        'Coarse Aggregate  (component 6)(kg in a m^3 mixture)',
#        'Fine Aggregate (component 7)(kg in a m^3 mixture)', 'Age (day)',
#        'Concrete compressive strength(MPa, megapascals) '],
#       dtype='object')

# %%
Data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Cement (component 1)(kg in a m^3 mixture)              1030 non-null   float64
#  1   Blast Furnace Slag (component 2)(kg in a m^3 mixture)  1030 non-null   float64
#  2   Fly Ash (component 3)(kg in a m^3 mixture)             1030 non-null   float64
#  3   Water  (component 4)(kg in a m^3 mixture)              1030 non-null   float64
#  4   Superplasticizer (component 5)(kg in a m^3 mixture)    1030 non-null   float64
#  5   Coarse Aggregate  (component 6)(kg in a m^3 mixture)   1030 non-null   float64
#  6   Fine Aggregate (component 7)(kg in a m^3 mixture)      1030 non-null   float64
#  7   Age (day)                                              1030 non-null   int64
# ...

# %%
Data_set.describe()
# Out:
#        Cement (component 1)(kg in a m^3 mixture)  ...  Concrete compressive strength(MPa, megapascals)
# count                                1030.000000  ...                                       1030.000000
# mean                                  281.167864  ...                                         35.817961
# std                                   104.506364  ...                                         16.705742
# min                                   102.000000  ...                                          2.330000
# 25%                                   192.375000  ...                                         23.710000
# 50%                                   272.900000  ...                                         34.445000
# 75%                                   350.000000  ...                                         46.135000
# max                                   540.000000  ...                                         82.600000
#
# [8 rows x 9 columns]

# %%
Data_set.isnull().sum()
# Out:
# Cement (component 1)(kg in a m^3 mixture)                0
# Blast Furnace Slag (component 2)(kg in a m^3 mixture)    0
# Fly Ash (component 3)(kg in a m^3 mixture)               0
# Water  (component 4)(kg in a m^3 mixture)                0
# Superplasticizer (component 5)(kg in a m^3 mixture)      0
# Coarse Aggregate  (component 6)(kg in a m^3 mixture)     0
# Fine Aggregate (component 7)(kg in a m^3 mixture)        0
# Age (day)                                                0
# Concrete compressive strength(MPa, megapascals)          0
# dtype: int64

# %%
Data_set.shape
# Out:
# (1030, 9)

# %%
change_names = ["Cement", "BlastSlag", "Ash", "Water", "Superplastic","Coarse", "FineAge", "Age", "C_strength"]

now_names = list(Data_set.columns)

mapper = {}
for i,name in enumerate(now_names):
  mapper[name] = change_names[i]

Data_set = Data_set.rename(columns=mapper)

# %%
Data_set.head()
# Out:
#    Cement  BlastSlag  Ash  Water  ...  Coarse  FineAge  Age  C_strength
# 0   540.0        0.0  0.0  162.0  ...  1040.0    676.0   28       79.99
# 1   540.0        0.0  0.0  162.0  ...  1055.0    676.0   28       61.89
# 2   332.5      142.5  0.0  228.0  ...   932.0    594.0  270       40.27
# 3   332.5      142.5  0.0  228.0  ...   932.0    594.0  365       41.05
# 4   198.6      132.4  0.0  192.0  ...   978.4    825.5  360       44.30
#
# [5 rows x 9 columns]

# %%
Data_set.describe().T
# Out:
#                count        mean         std  ...      50%       75%     max
# Cement        1030.0  281.167864  104.506364  ...  272.900   350.000   540.0
# BlastSlag     1030.0   73.895825   86.279342  ...   22.000   142.950   359.4
# Ash           1030.0   54.188350   63.997004  ...    0.000   118.300   200.1
# Water         1030.0  181.567282   21.354219  ...  185.000   192.000   247.0
# Superplastic  1030.0    6.204660    5.973841  ...    6.400    10.200    32.2
# Coarse        1030.0  972.918932   77.753954  ...  968.000  1029.400  1145.0
# FineAge       1030.0  773.580485   80.175980  ...  779.500   824.000   992.6
# Age           1030.0   45.662136   63.169912  ...   28.000    56.000   365.0
# C_strength    1030.0   35.817961   16.705742  ...   34.445    46.135    82.6
#
# [9 rows x 8 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.pairplot(Data_set)
plt.show()

# %%
corr = Data_set.corr()

plt.figure(figsize= (10,9))
sns.heatmap(corr, annot = True, cmap = 'Blues')
b, t = plt.ylim()
plt.ylim(b+0.5, t-0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
ax = sns.distplot(Data_set['C_strength'])
ax.set_title('Compressive Strength Distribution')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Compressive Strength Distribution')

# %%
counts,bin_edges = np.histogram(Data_set['C_strength'],bins = 10, density = True)
print(counts)
print('')
plt.xlabel('C_strength')
pdf = counts/sum(counts)
print(pdf)
print('')
print(bin_edges)
plt.plot(bin_edges[1:],pdf)
# Out:
# [0.0054428  0.01608648 0.01886836 0.02189213 0.0237064  0.01354651
#  0.0120951  0.00628945 0.00435424 0.00229807]
#
# [0.04368932 0.12912621 0.15145631 0.17572816 0.19029126 0.10873786
#  0.09708738 0.05048544 0.03495146 0.0184466 ]
#
# [ 2.33  10.357 18.384 26.411 34.438 42.465 50.492 58.519 66.546 74.573
#  82.6  ]

# %%
X = Data_set.iloc[:,0:7]

# %%
X
# Out:
#       Cement  BlastSlag    Ash  Water  Superplastic  Coarse  FineAge
# 0      540.0        0.0    0.0  162.0           2.5  1040.0    676.0
# 1      540.0        0.0    0.0  162.0           2.5  1055.0    676.0
# 2      332.5      142.5    0.0  228.0           0.0   932.0    594.0
# 3      332.5      142.5    0.0  228.0           0.0   932.0    594.0
# 4      198.6      132.4    0.0  192.0           0.0   978.4    825.5
# ...      ...        ...    ...    ...           ...     ...      ...
# 1025   276.4      116.0   90.3  179.6           8.9   870.1    768.3
# 1026   322.2        0.0  115.6  196.0          10.4   817.9    813.4
# 1027   148.5      139.4  108.6  192.7           6.1   892.4    780.0
# 1028   159.1      186.7    0.0  175.6          11.3   989.6    788.9
# 1029   260.9      100.5   78.3  200.6           8.6   864.5    761.5
#
# [1030 rows x 7 columns]

# %%
y_target = Data_set['C_strength'] # Strength column
y_target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: C_strength, dtype: float64

# %%
X_cols = X.shape[1]

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import layers
from keras import models

# %%
def regression_model():
    # create model
    model0 = models.Sequential()
    model0.add(layers.Dense(10, activation='relu', input_shape=(X_cols,)))
    model0.add(layers.Dense(8, activation= 'relu'))
    model0.add(layers.Dense(6, activation='relu'))
    model0.add(layers.Dense(1))
    
    # compile model
    model0.compile(optimizer='rmsprop', loss='mean_squared_error',metrics=['mae'])
    return model0

# %%
model_relu = regression_model()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Define a function to build a list of mean squared errors 
# with the model, predictor values and number of epochs as arguments
def calcul_MSE(model, predictor, num_epochs):

    MSE_list = []
    Repetition = 100

    for i in range(Repetition):

        X_train, X_test, y_train, y_test = train_test_split(X, y_target, test_size=0.3, random_state=None)

        # fit the model and train the model on the training data using 50 epochs.
        model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=num_epochs, verbose=2)

        # Make predictions using the testing set
        strength_y_pred = model.predict(X_test)

        # The mean squared error
        MSE = mean_squared_error(y_test, strength_y_pred)
        print(f'--------- MSE {i+1}/{Repetition} = {MSE:.2f}------------------------------------------')
        MSE_list.append(MSE)
    
    return MSE_list

# %%
MSE_list_A = calcul_MSE(model_relu, X, 100)
# Out:
# Streaming output truncated to the last 5000 lines.
# 23/23 - 0s - loss: 123.4979 - mae: 8.9160 - val_loss: 124.6621 - val_mae: 8.8139
# Epoch 14/100
# 23/23 - 0s - loss: 119.5322 - mae: 8.7718 - val_loss: 140.4283 - val_mae: 9.1927
# Epoch 15/100
# 23/23 - 0s - loss: 122.3125 - mae: 8.9038 - val_loss: 128.8662 - val_mae: 9.0557
# Epoch 16/100
# 23/23 - 0s - loss: 121.6284 - mae: 8.8688 - val_loss: 127.8628 - val_mae: 9.0689
# Epoch 17/100
# 23/23 - 0s - loss: 120.8621 - mae: 8.8162 - val_loss: 130.2449 - val_mae: 9.1750
# Epoch 18/100
# 23/23 - 0s - loss: 121.0179 - mae: 8.8270 - val_loss: 137.6952 - val_mae: 9.1954
# Epoch 19/100
# 23/23 - 0s - loss: 122.9815 - mae: 8.9543 - val_loss: 124.3909 - val_mae: 8.9350
# Epoch 20/100
# 23/23 - 0s - loss: 121.3989 - mae: 8.8403 - val_loss: 123.7163 - val_mae: 8.7688
# Epoch 21/100
# 23/23 - 0s - loss: 121.8597 - mae: 8.8273 - val_loss: 125.9550 - val_mae: 8.9101
# Epoch 22/100
# ...

# %%
# Calculate the length, the mean and the standard deviation
length_MSE_A = len(MSE_list_A)
mean_MSE_A = np.mean(MSE_list_A)
sd_MSE_A = np.std(MSE_list_A)

# Print the values
print(f'Number of mean squared errors: {length_MSE_A}')
print(f'Mean of the mean squared errors: {mean_MSE_A:.2f}')
print(f'Standard deviation of the mean squared errors: {sd_MSE_A:.2f}')
# Out:
# Number of mean squared errors: 100
# Mean of the mean squared errors: 136.29
# Standard deviation of the mean squared errors: 11.60

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras import layers
from keras import models

def regression_model1():
    # create model
    model1 = models.Sequential()
    model1.add(layers.Dense(10, activation='tanh', input_shape=(X_cols,)))
    model1.add(layers.Dense(8, activation= 'tanh'))
    model1.add(layers.Dense(6, activation='tanh'))
    model1.add(layers.Dense(1))
    
    # compile model
    model1.compile(optimizer='rmsprop', loss='mean_squared_error',metrics=['mae'])
    return model1

# %%
model_tanh = regression_model1()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Define a function to build a list of mean squared errors 
# with the model, predictor values and number of epochs as arguments
def calcul_MSEb(model, predictor, num_epochs):

    MSE_list1 = []
    Repetition = 100

    for i in range(Repetition):

        X_train, X_test, y_train, y_test = train_test_split(X, y_target, test_size=0.3, random_state=None)

        # fit the model and train the model on the training data using 50 epochs.
        model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=num_epochs, verbose=2)

        # Make predictions using the testing set
        strength_y_pred = model.predict(X_test)

        # The mean squared error
        MSE = mean_squared_error(y_test, strength_y_pred)
        print(f'--------- MSE {i+1}/{Repetition} = {MSE:.2f}------------------------------------------')
        MSE_list1.append(MSE)
    
    return MSE_list1

# %%
MSE_list_b = calcul_MSEb(model_tanh, X, 100)
# Out:
# Streaming output truncated to the last 5000 lines.
# 23/23 - 0s - loss: 276.3330 - mae: 13.3921 - val_loss: 285.0993 - val_mae: 13.5662
# Epoch 14/100
# 23/23 - 0s - loss: 276.3229 - mae: 13.3933 - val_loss: 285.0910 - val_mae: 13.5671
# Epoch 15/100
# 23/23 - 0s - loss: 276.3162 - mae: 13.3923 - val_loss: 285.0773 - val_mae: 13.5689
# Epoch 16/100
# 23/23 - 0s - loss: 276.2901 - mae: 13.3936 - val_loss: 285.0686 - val_mae: 13.5701
# Epoch 17/100
# 23/23 - 0s - loss: 276.3041 - mae: 13.3932 - val_loss: 285.0663 - val_mae: 13.5704
# Epoch 18/100
# 23/23 - 0s - loss: 276.2858 - mae: 13.3944 - val_loss: 285.0555 - val_mae: 13.5720
# Epoch 19/100
# 23/23 - 0s - loss: 276.2805 - mae: 13.3947 - val_loss: 285.0518 - val_mae: 13.5726
# Epoch 20/100
# 23/23 - 0s - loss: 276.2649 - mae: 13.3943 - val_loss: 285.0444 - val_mae: 13.5738
# Epoch 21/100
# 23/23 - 0s - loss: 276.2548 - mae: 13.3950 - val_loss: 285.0349 - val_mae: 13.5755
# Epoch 22/100
# ...

# %%
length_MSE_b = len(MSE_list_b)
mean_MSE_b = np.mean(MSE_list_b)
sd_MSE_b = np.std(MSE_list_b)
# Print the values
print(f'Number of mean squared errors: {length_MSE_b}')
print(f'Mean of the mean squared errors: {mean_MSE_b:.2f}')
print(f'Standard deviation of the mean squared errors: {sd_MSE_b:.2f}')
# Out:
# Number of mean squared errors: 100
# Mean of the mean squared errors: 277.14
# Standard deviation of the mean squared errors: 17.49

# %%
dataset_norm = (X - X.mean()) / X.std()
dataset_norm.head()
# Out:
#      Cement  BlastSlag       Ash     Water  Superplastic    Coarse   FineAge
# 0  2.476712  -0.856472 -0.846733 -0.916319     -0.620147  0.862735 -1.217079
# 1  2.476712  -0.856472 -0.846733 -0.916319     -0.620147  1.055651 -1.217079
# 2  0.491187   0.795140 -0.846733  2.174405     -1.038638 -0.526262 -2.239829
# 3  0.491187   0.795140 -0.846733  2.174405     -1.038638 -0.526262 -2.239829
# 4 -0.790075   0.678079 -0.846733  0.488555     -1.038638  0.070492  0.647569

# %%
MSE_list_2 = calcul_MSE(model_relu, dataset_norm, 100)
# Out:
# Streaming output truncated to the last 5000 lines.
# 23/23 - 0s - loss: 118.9734 - mae: 8.7626 - val_loss: 113.0773 - val_mae: 8.5586
# Epoch 14/100
# 23/23 - 0s - loss: 118.1955 - mae: 8.7063 - val_loss: 126.4569 - val_mae: 8.9518
# Epoch 15/100
# 23/23 - 0s - loss: 118.1915 - mae: 8.7466 - val_loss: 112.2727 - val_mae: 8.3012
# Epoch 16/100
# 23/23 - 0s - loss: 119.3817 - mae: 8.7542 - val_loss: 114.7775 - val_mae: 8.5463
# Epoch 17/100
# 23/23 - 0s - loss: 117.9033 - mae: 8.7132 - val_loss: 134.2897 - val_mae: 9.5164
# Epoch 18/100
# 23/23 - 0s - loss: 119.9275 - mae: 8.7422 - val_loss: 115.4355 - val_mae: 8.3622
# Epoch 19/100
# 23/23 - 0s - loss: 118.1918 - mae: 8.7119 - val_loss: 115.0198 - val_mae: 8.5581
# Epoch 20/100
# 23/23 - 0s - loss: 119.5523 - mae: 8.7478 - val_loss: 117.2285 - val_mae: 8.6373
# Epoch 21/100
# 23/23 - 0s - loss: 118.4712 - mae: 8.7570 - val_loss: 114.7786 - val_mae: 8.3702
# Epoch 22/100
# ...

# %%
length_MSE_relu2 = len(MSE_list_2)
mean_MSE_relu2 = np.mean(MSE_list_2)
sd_MSE_relu2= np.std(MSE_list_2)
# Print the values
print(f'Number of mean squared errors: {length_MSE_relu2}')
print(f'Mean of the mean squared errors: {mean_MSE_relu2:.2f}')
print(f'Standard deviation of the mean squared errors: {sd_MSE_relu2:.2f}')
# Out:
# Number of mean squared errors: 100
# Mean of the mean squared errors: 128.20
# Standard deviation of the mean squared errors: 9.89

# %%
def regression_model_tan3hl():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='tanh', input_shape=(X_cols,)))
    model.add(Dense(8, activation='tanh'))
    model.add(Dense(6, activation='tanh'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
model_tanh2 = regression_model_tan3hl()

# %%
MSE_list_D = calcul_MSE(model_tanh2, dataset_norm, 100)
# Out:
# Streaming output truncated to the last 5000 lines.
# 23/23 - 0s - loss: 173.8412 - val_loss: 187.1949
# Epoch 14/100
# 23/23 - 0s - loss: 173.4638 - val_loss: 184.7685
# Epoch 15/100
# 23/23 - 0s - loss: 175.8206 - val_loss: 191.2722
# Epoch 16/100
# 23/23 - 0s - loss: 172.8554 - val_loss: 199.0504
# Epoch 17/100
# 23/23 - 0s - loss: 183.4089 - val_loss: 203.0444
# Epoch 18/100
# 23/23 - 0s - loss: 183.1859 - val_loss: 201.3635
# Epoch 19/100
# 23/23 - 0s - loss: 183.3488 - val_loss: 201.4426
# Epoch 20/100
# 23/23 - 0s - loss: 182.6637 - val_loss: 201.4034
# Epoch 21/100
# 23/23 - 0s - loss: 180.7849 - val_loss: 197.7823
# Epoch 22/100
# 23/23 - 0s - loss: 180.6125 - val_loss: 197.7871
# Epoch 23/100
# 23/23 - 0s - loss: 180.3905 - val_loss: 197.3587
# Epoch 24/100
# 23/23 - 0s - loss: 180.2139 - val_loss: 197.1430
# Epoch 25/100
# 23/23 - 0s - loss: 173.8134 - val_loss: 191.2753
# Epoch 26/100
# 23/23 - 0s - loss: 172.4841 - val_loss: 183.8515
# Epoch 27/100
# ...

# %%
length_MSE_tanh2 = len(MSE_list_D)
mean_MSE_tanh2 = np.mean(MSE_list_D)
sd_MSE_tanh2 = np.std(MSE_list_D)

# Print the values
print(f'Number of mean squared errors: {length_MSE_tanh2}')
print(f'Mean of the mean squared errors: {mean_MSE_tanh2:.2f}')
print(f'Standard deviation of the mean squared errors: {sd_MSE_tanh2:.2f}')
# Out:
# Number of mean squared errors: 100
# Mean of the mean squared errors: 198.96
# Standard deviation of the mean squared errors: 51.43

# %%
# initialise data of lists. 
data = {'Relu 1before normaliz':[mean_MSE_A , sd_MSE_A], 'Tanh1 before normaliz':[mean_MSE_b , sd_MSE_b],
        'Relu 2after normaliz':[mean_MSE_relu2 , sd_MSE_relu2], 'Tanh2 after normaliz':[mean_MSE_tanh2 , sd_MSE_tanh2]} 
  
# Creates pandas DataFrame. 
df = pd.DataFrame(df, index =['Mean', 'StD'])
df = df.round(2)
  
# print the data 
df
# Out:
#       Relu 1before normaliz  ...  Tanh2 after normaliz
# Mean                 136.29  ...                198.96
# StD                   11.60  ...                 51.43
#
# [2 rows x 4 columns]
